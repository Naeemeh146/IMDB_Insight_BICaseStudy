# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('imdbdata_maindata2.csv')
df.head(3)
# Out:
#               title       year  rated     released runtime  \
# 0        The Player       2015  TV-14  24 Sep 2015  60 min
# 1  The Honeymooners  1955–1956    NaN  01 Oct 1955  30 min
# 2     McHale's Navy  1962–1966   TV-G  11 Oct 1962  30 min
#
#                   genre director                 writer  \
# 0  Action, Crime, Drama      NaN  John Fox, John Rogers
# 1        Comedy, Family      NaN         Jackie Gleason
# 2           Comedy, War      NaN                    NaN
#
#                                               actors  \
# 0  Philip Winchester, Damon Gupton, Wesley Snipes...
# 1  Jackie Gleason, Art Carney, Audrey Meadows, Jo...
# 2  Ernest Borgnine, Joe Flynn, Tim Conway, Carl B...
#
#                                                 plot  ... imdbrating  \
# 0  A former intelligence and FBI officer, who now...  ...        7.1
# 1  A bus driver and his sewer worker friend strug...  ...        8.7
# 2  The misadventures of a misfit PT Boat crew dur...  ...        7.5
#
# ...

# %%
# Convert 'Date' column to datetime format
df['released'] = pd.to_datetime(df['released'])
df['released year'] = df['released'].dt.year.astype('Int64')

# %%
df.head(3)
# Out:
#               title       year  rated   released runtime  \
# 0        The Player       2015  TV-14 2015-09-24  60 min
# 1  The Honeymooners  1955–1956    NaN 1955-10-01  30 min
# 2     McHale's Navy  1962–1966   TV-G 1962-10-11  30 min
#
#                   genre director                 writer  \
# 0  Action, Crime, Drama      NaN  John Fox, John Rogers
# 1        Comedy, Family      NaN         Jackie Gleason
# 2           Comedy, War      NaN                    NaN
#
#                                               actors  \
# 0  Philip Winchester, Damon Gupton, Wesley Snipes...
# 1  Jackie Gleason, Art Carney, Audrey Meadows, Jo...
# 2  Ernest Borgnine, Joe Flynn, Tim Conway, Carl B...
#
#                                                 plot  ... imdbvotes  \
# 0  A former intelligence and FBI officer, who now...  ...      6331
# 1  A bus driver and his sewer worker friend strug...  ...      3637
# 2  The misadventures of a misfit PT Boat crew dur...  ...      1698
#
# ...

# %%
df['rated'].unique()
# Out:
# array(['TV-14', nan, 'TV-G', 'TV-PG', 'TV-MA', 'TV-Y', 'TV-Y7',
#        'NOT RATED', 'PG', 'R', 'PG-13', 'UNRATED', 'G', 'APPROVED',
#        'PASSED', 'GP', 'NC-17', 'M', 'M/PG', 'X'], dtype=object)

# %%
#f.to_excel('IMDB_Data.xlsx', 'IMDB')
